# %%
import cv2
import numpy as np

# %%
# !ls
# Out:
# Images	opencv_Introduction.ipynb

# %%
input_1 = cv2.imread('./Images/Obama.jpg')

# %%
cv2.imshow('Barack Obama', input_1)

# After pressing any key -> Closes
cv2.waitKey()

# Closes all the open windows
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
plt.imshow(input_1)

# %%
# Here the color space seems not to be correct
# Because while opencv reads the image it reads in BGR format
# So to fix this 
# We need to change into RGB format.

plt.imshow(cv2.cvtColor(input_1, cv2.COLOR_BGR2RGB))

# %%
# Image as the matrix
# Height , Width and RGB 
print(input_1.shape)
# Out:
# (3356, 2687, 3)

# %%
input_1
# Out:
# array([[[ 32,  34,  98],
#         [ 30,  33,  94],
#         [ 27,  30,  91],
#         ...,
#         [ 89,  94, 193],
#         [ 91,  96, 195],
#         [ 90,  95, 194]],
#
#        [[ 32,  34,  98],
#         [ 29,  32,  93],
#         [ 27,  30,  91],
#         ...,
#         [ 88,  93, 192],
#         [ 91,  96, 195],
#         [ 90,  95, 194]],
#
#        [[ 31,  33,  97],
#         [ 29,  32,  93],
#         [ 26,  29,  90],
#         ...,
#         [ 87,  92, 191],
#         [ 90,  95, 194],
#         [ 90,  95, 194]],
#
#        ...,
#
#        [[ 34,  74, 122],
#         [ 34,  74, 122],
#         [ 35,  75, 123],
#         ...,
#         [ 11,  50,  89],
#         [ 15,  51,  91],
#         [ 14,  49,  89]],
#
#        [[ 33,  71, 119],
#         [ 33,  71, 119],
#         [ 34,  72, 120],
#         ...,
#         [ 10,  49,  88],
#         [ 14,  50,  90],
#         [ 13,  48,  88]],
#
#        [[ 31,  67, 115],
#         [ 31,  67, 115],
#         [ 32,  68, 116],
# ...

# %%
# Height 
print('Height of the image', int(input_1.shape[0]))

# Width 
print('Width of the image', int(input_1.shape[1]))

# RGB
print('RGB', int(input_1.shape[2]))
# Out:
# Height of the image 3356
# Width of the image 2687
# RGB 3

# %%
# Normalization 

normalized_input = input_1 / 255.0

# %%
plt.imshow(normalized_input)
